# %%
import WaveData
WaveData.save_excel(coordinate_data= 'Jalur Pelayaran.xlsx',
                    nama_file= '05 Januari 2022.xlsx')
# Out:
#      coordinate 0 Wave Height  coordinate 0 Wave Direction  \
# 0                        0.54                       304.21
# 1                        0.56                       306.04
# 2                        0.59                       307.88
# 3                        0.61                       309.71
# 4                        0.65                       312.20
# ..                        ...                          ...
# 236                       NaN                          NaN
# 237                       NaN                          NaN
# 238                       NaN                          NaN
# 239                       NaN                          NaN
# 240                       NaN                          NaN
#
#      coordinate 0 Wave Period  coordinate 1 Wave Height  \
# 0                        3.81                      1.20
# 1                        3.84                      1.19
# 2                        3.87                      1.18
# ...
